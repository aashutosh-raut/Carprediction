# %% [markdown]
# https://github.com/aashutosh-raut/Carprediction

# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:9000") 
mlflow.set_experiment(experiment_name="experimentA2_7ashucopy2")
# Out:
# 2025/09/13 06:47:38 INFO mlflow.tracking.fluent: Experiment with name 'experimentA2_7ashucopy2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/825546618770816377', creation_time=1757720858699, experiment_id='825546618770816377', last_update_time=1757720858699, lifecycle_stage='active', name='experimentA2_7ashucopy2', tags={}>

# %%
import numpy as np #importing the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib
np.__version__, pd.__version__, sns.__version__, matplotlib.__version__
# Out:
# ('2.1.3', '2.2.3', '0.13.2', '3.10.0')

# %%
df = pd.read_csv('Cars.csv') #importing/loading the data set

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df.shape # Checking the number of data and columns
# Out:
# (8128, 13)

# %%
df.describe() # here we describe the data, see what the rows and columns have
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]>

# %%
df.columns # here we see what are the columns (features we will later take to train test the model. some of them we will use some we will drop.) now we will rename the columns below.
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.rename(columns = {'name': 'brand', 'year': 'year', 'selling_price': 'selling_price', 'km_driven': 'km_driven', 'fuel': 'fuel', 'seller_type': 'seller_type', 'transmission': 'transmission', 'owner': 'owner', 'mileage': 'milage',  'engine': 'engine', 'max_power': 'max_power', 'torque': 'torque', 'seats': 'seats'}, inplace = True)
# The above is the renaming process of the Exploratory (EDA)

# %%
df.columns # checking the updated columns names
# Out:
# Index(['brand', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'milage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df['owner'].unique() # checking the data in the owner column
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
df['owner'] = df['owner'].replace({
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4,
    'Test Drive Car': 5
}) # changing the string into numeric values
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\3554053464.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['owner'] = df['owner'].replace({

# %%
df['owner'].unique() # checking the updated data
# Out:
# array([1, 2, 3, 4, 5])

# %%
df
# Out:
#                              brand  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission  owner      milage   engine   max_power  \
# 0     Individual       Manual      1   23.4 kmpl  1248 CC      74 bhp
# 1     Individual       Manual      2  21.14 kmpl  1498 CC  103.52 bhp
# 2     Individual       Manual      3   17.7 kmpl  1497 CC      78 bhp
# 3     Individual       Manual      1   23.0 kmpl  1396 CC      90 bhp
# 4     Individual       Manual      1   16.1 kmpl  1298 CC    88.2 bhp
# ...          ...          ...    ...         ...      ...         ...
# 8123  Individual       Manual      1   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Individual       Manual      4   16.8 kmpl  1493 CC     110 bhp
# 8125  Individual       Manual      1   19.3 kmpl  1248 CC    73.9 bhp
# 8126  Individual       Manual      1  23.57 kmpl  1396 CC      70 bhp
# 8127  Individual       Manual      1  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
df['fuel'].unique() # checking the data in the fuel column
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df = df[df['fuel'] != 'LPG']
df['fuel'] #droping LPG from the data
# Out:
# 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# 8126    Diesel
# 8127    Diesel
# Name: fuel, Length: 8090, dtype: object

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
df = df[df['fuel'] != 'CNG']
df['fuel'] #dropping CNG from the data
# Out:
# 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# 8126    Diesel
# 8127    Diesel
# Name: fuel, Length: 8033, dtype: object

# %%
df['fuel'].unique() # checking if LPG and CNG have been dropped from the data
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %%
df['milage'].unique()
# Out:
# array(['23.4 kmpl', '21.14 kmpl', '17.7 kmpl', '23.0 kmpl', '16.1 kmpl',
#        '20.14 kmpl', '23.59 kmpl', '20.0 kmpl', '19.01 kmpl', '17.3 kmpl',
#        '19.3 kmpl', nan, '18.9 kmpl', '18.15 kmpl', '24.52 kmpl',
#        '19.7 kmpl', '22.54 kmpl', '21.0 kmpl', '25.5 kmpl', '26.59 kmpl',
#        '21.5 kmpl', '20.3 kmpl', '21.4 kmpl', '24.7 kmpl', '18.2 kmpl',
#        '16.8 kmpl', '24.3 kmpl', '14.0 kmpl', '18.6 kmpl', '23.95 kmpl',
#        '17.0 kmpl', '20.63 kmpl', '13.93 kmpl', '16.0 kmpl', '17.8 kmpl',
#        '18.5 kmpl', '12.55 kmpl', '12.99 kmpl', '14.8 kmpl', '13.5 kmpl',
#        '26.0 kmpl', '20.65 kmpl', '27.3 kmpl', '11.36 kmpl', '17.68 kmpl',
#        '14.28 kmpl', '18.53 kmpl', '14.84 kmpl', '21.12 kmpl',
#        '20.36 kmpl', '21.27 kmpl', '18.16 kmpl', '22.0 kmpl', '25.1 kmpl',
#        '20.51 kmpl', '21.66 kmpl', '25.2 kmpl', '22.9 kmpl', '16.02 kmpl',
#        '20.54 kmpl', '22.77 kmpl', '15.71 kmpl', '23.1 kmpl',
#        '19.02 kmpl', '19.81 kmpl', '16.47 kmpl', '15.04 kmpl',
#        '19.1 kmpl', '21.79 kmpl', '18.8 kmpl', '21.21 kmpl', '15.37 kmpl',
#        '11.79 kmpl', '19.0 kmpl', '14.3 kmpl', '15.8 kmpl', '15.1 kmpl',
#        '19.09 kmpl', '22.32 kmpl', '21.9 kmpl', '14.53 kmpl',
#        '21.63 kmpl', '20.85 kmpl', '20.45 kmpl', '19.67 kmpl',
#        '23.01 kmpl', '20.77 kmpl', '17.92 kmpl', '17.01 kmpl',
#        '22.37 kmpl', '19.33 kmpl', '9.5 kmpl', '12.83 kmpl', '22.48 kmpl',
#        '16.78 kmpl', '14.67 kmpl', '15.0 kmpl', '13.96 kmpl', '18.0 kmpl',
#        '12.07 kmpl', '26.21 kmpl', '10.8 kmpl', '16.3 kmpl', '13.6 kmpl',
#        '14.74 kmpl', '15.6 kmpl', '19.56 kmpl', '22.69 kmpl',
#        '19.16 kmpl', '18.12 kmpl', '12.1 kmpl', '17.5 kmpl', '42.0 kmpl',
#        '20.4 kmpl', '21.1 kmpl', '19.44 kmpl', '13.0 kmpl', '21.43 kmpl',
#        '22.95 kmpl', '16.2 kmpl', '15.3 kmpl', '28.09 kmpl', '17.4 kmpl',
#        '19.4 kmpl', '17.6 kmpl', '28.4 kmpl', '14.1 kmpl', '25.17 kmpl',
#        '22.74 kmpl', '17.57 kmpl', '16.95 kmpl', '19.49 kmpl',
#        '17.21 kmpl', '13.2 kmpl', '14.2 kmpl', '26.8 kmpl', '25.4 kmpl',
#        '11.5 kmpl', '27.28 kmpl', '17.97 kmpl', '12.8 kmpl', '16.55 kmpl',
#        '12.05 kmpl', '14.07 kmpl', '21.02 kmpl', '11.57 kmpl',
#        '17.9 kmpl', '15.96 kmpl', '17.1 kmpl', '17.19 kmpl', '21.01 kmpl',
#        '24.0 kmpl', '25.6 kmpl', '21.38 kmpl', '23.84 kmpl', '23.08 kmpl',
#        '14.24 kmpl', '20.71 kmpl', '15.64 kmpl', '14.5 kmpl',
#        '16.34 kmpl', '27.39 kmpl', '11.1 kmpl', '13.9 kmpl', '20.92 kmpl',
#        '23.8 kmpl', '24.4 kmpl', '15.29 kmpl', '21.19 kmpl', '22.5 kmpl',
#        '19.6 kmpl', '23.65 kmpl', '25.32 kmpl', '23.5 kmpl', '16.6 kmpl',
#        '23.9 kmpl', '20.8 kmpl', '27.62 kmpl', '12.9 kmpl', '25.44 kmpl',
#        '17.88 kmpl', '22.7 kmpl', '17.2 kmpl', '15.42 kmpl', '19.68 kmpl',
#        '18.7 kmpl', '15.4 kmpl', '19.34 kmpl', '22.71 kmpl', '25.8 kmpl',
#        '13.7 kmpl', '12.2 kmpl', '18.49 kmpl', '9.0 kmpl', '0.0 kmpl',
#        '13.58 kmpl', '10.1 kmpl', '20.5 kmpl', '25.0 kmpl', '10.5 kmpl',
#        '22.07 kmpl', '22.3 kmpl', '15.26 kmpl', '20.62 kmpl', '27.4 kmpl',
#        '23.2 kmpl', '14.4 kmpl', '18.4 kmpl', '14.02 kmpl', '11.0 kmpl',
#        '20.6 kmpl', '22.05 kmpl', '20.2 kmpl', '18.1 kmpl', '22.1 kmpl',
#        '19.87 kmpl', '13.01 kmpl', '18.06 kmpl', '26.1 kmpl',
#        '16.52 kmpl', '13.55 kmpl', '24.2 kmpl', '25.83 kmpl', '11.2 kmpl',
#        '17.09 kmpl', '21.03 kmpl', '17.45 kmpl', '21.64 kmpl',
#        '13.87 kmpl', '19.98 kmpl', '20.52 kmpl', '23.57 kmpl',
#        '11.7 kmpl', '17.43 kmpl', '18.88 kmpl', '13.68 kmpl',
#        '11.18 kmpl', '20.89 kmpl', '11.8 kmpl', '19.62 kmpl', '21.7 kmpl',
#        '14.9 kmpl', '19.5 kmpl', '10.91 kmpl', '15.7 kmpl', '20.73 kmpl',
#        '15.85 kmpl', '20.7 kmpl', '14.23 kmpl', '16.5 kmpl', '17.36 kmpl',
#        '12.6 kmpl', '16.36 kmpl', '14.95 kmpl', '16.9 kmpl', '19.2 kmpl',
#        '16.96 kmpl', '22.15 kmpl', '18.78 kmpl', '19.61 kmpl',
#        '17.71 kmpl', '18.3 kmpl', '19.12 kmpl', '19.72 kmpl', '12.0 kmpl',
#        '11.4 kmpl', '23.03 kmpl', '11.07 kmpl', '15.9 kmpl', '17.67 kmpl',
#        '20.46 kmpl', '13.1 kmpl', '24.8 kmpl', '15.73 kmpl', '15.11 kmpl',
#        '12.7 kmpl', '21.2 kmpl', '20.38 kmpl', '21.56 kmpl', '13.22 kmpl',
#        '14.49 kmpl', '15.05 kmpl', '23.26 kmpl', '15.41 kmpl',
#        '13.8 kmpl', '22.27 kmpl', '14.66 kmpl', '12.12 kmpl',
#        '16.84 kmpl', '14.09 kmpl', '14.7 kmpl', '13.4 kmpl', '15.5 kmpl',
#        '13.49 kmpl', '14.6 kmpl', '10.75 kmpl', '24.5 kmpl', '11.74 kmpl',
#        '16.07 kmpl', '15.63 kmpl', '25.47 kmpl', '17.05 kmpl',
#        '23.3 kmpl', '11.9 kmpl', '13.38 kmpl', '20.86 kmpl', '10.9 kmpl',
#        '18.25 kmpl', '15.2 kmpl', '20.37 kmpl', '21.8 kmpl', '11.96 kmpl',
#        '24.04 kmpl', '19.69 kmpl', '13.73 kmpl', '21.04 kmpl',
#        '25.01 kmpl', '10.93 kmpl', '24.29 kmpl', '13.44 kmpl',
#        '20.07 kmpl', '19.08 kmpl', '20.34 kmpl', '11.68 kmpl',
#        '12.5 kmpl', '12.3 kmpl', '23.87 kmpl', '16.38 kmpl', '17.42 kmpl',
#        '10.0 kmpl', '18.24 kmpl', '10.71 kmpl', '19.59 kmpl', '16.7 kmpl',
#        '19.83 kmpl', '21.76 kmpl', '16.05 kmpl', '20.28 kmpl',
#        '16.25 kmpl', '16.73 kmpl', '18.48 kmpl', '14.99 kmpl',
#        '18.76 kmpl', '16.4 kmpl', '19.64 kmpl', '14.94 kmpl',
#        '17.11 kmpl', '12.4 kmpl', '18.44 kmpl', '16.09 kmpl',
#        '12.62 kmpl', '21.13 kmpl', '15.17 kmpl', '21.73 kmpl',
#        '21.72 kmpl', '12.85 kmpl', '14.81 kmpl', '13.24 kmpl',
#        '21.49 kmpl', '14.62 kmpl', '11.45 kmpl', '12.08 kmpl',
#        '15.74 kmpl', '11.3 kmpl', '14.21 kmpl', '11.72 kmpl',
#        '16.51 kmpl'], dtype=object)

# %%
df['milage'] = df['milage'].str.split(' ').str[0]
df['milage']
# Out:
# 0        23.4
# 1       21.14
# 2        17.7
# 3        23.0
# 4        16.1
#         ...
# 8123     18.5
# 8124     16.8
# 8125     19.3
# 8126    23.57
# 8127    23.57
# Name: milage, Length: 8033, dtype: object

# %%
df['milage'].dtype
# Out:
# dtype('O')

# %%
df['milage'] = df['milage'].astype(float)
df['milage'].dtype
# Out:
# dtype('float64')

# %%
df['engine'].unique()
# Out:
# array(['1248 CC', '1498 CC', '1497 CC', '1396 CC', '1298 CC', '1197 CC',
#        '796 CC', '1364 CC', '1399 CC', '1461 CC', '993 CC', nan,
#        '1061 CC', '1198 CC', '1199 CC', '998 CC', '1591 CC', '2179 CC',
#        '1368 CC', '2982 CC', '2494 CC', '2143 CC', '2477 CC', '1462 CC',
#        '2755 CC', '1968 CC', '1798 CC', '1196 CC', '1373 CC', '1598 CC',
#        '1998 CC', '1086 CC', '1194 CC', '1172 CC', '1405 CC', '1582 CC',
#        '999 CC', '2487 CC', '1999 CC', '3604 CC', '2987 CC', '1995 CC',
#        '1451 CC', '1969 CC', '2967 CC', '2497 CC', '1797 CC', '1991 CC',
#        '2362 CC', '1493 CC', '1599 CC', '1341 CC', '1794 CC', '799 CC',
#        '1193 CC', '2696 CC', '1495 CC', '1186 CC', '1047 CC', '2498 CC',
#        '2956 CC', '2523 CC', '1120 CC', '624 CC', '1496 CC', '1984 CC',
#        '2354 CC', '814 CC', '793 CC', '1799 CC', '936 CC', '1956 CC',
#        '1997 CC', '1499 CC', '1948 CC', '2997 CC', '2489 CC', '2499 CC',
#        '2609 CC', '2953 CC', '1150 CC', '1994 CC', '1388 CC', '1527 CC',
#        '2199 CC', '995 CC', '2993 CC', '1586 CC', '1390 CC', '909 CC',
#        '2393 CC', '3198 CC', '1339 CC', '2835 CC', '2092 CC', '1595 CC',
#        '2496 CC', '1596 CC', '1597 CC', '2596 CC', '2148 CC', '1299 CC',
#        '1590 CC', '2231 CC', '2694 CC', '2200 CC', '1795 CC', '1896 CC',
#        '1796 CC', '1422 CC', '1489 CC', '2359 CC', '2197 CC', '2999 CC',
#        '1781 CC', '2650 CC', '1343 CC', '2446 CC', '3498 CC', '2198 CC',
#        '2776 CC', '1950 CC'], dtype=object)

# %%
df['engine'] = df['engine'].str.split(' ').str[0]
df['engine']
# Out:
# 0       1248
# 1       1498
# 2       1497
# 3       1396
# 4       1298
#         ...
# 8123    1197
# 8124    1493
# 8125    1248
# 8126    1396
# 8127    1396
# Name: engine, Length: 8033, dtype: object

# %%
df['engine'] = df['engine'].astype(float)
df['engine'].dtype
# Out:
# dtype('float64')

# %%
df['max_power']
# Out:
# 0           74 bhp
# 1       103.52 bhp
# 2           78 bhp
# 3           90 bhp
# 4         88.2 bhp
#            ...
# 8123     82.85 bhp
# 8124       110 bhp
# 8125      73.9 bhp
# 8126        70 bhp
# 8127        70 bhp
# Name: max_power, Length: 8033, dtype: object

# %%
df['max_power'] = df['max_power'].str.split(' ').str[0]
df['max_power']
# Out:
# 0           74
# 1       103.52
# 2           78
# 3           90
# 4         88.2
#          ...
# 8123     82.85
# 8124       110
# 8125      73.9
# 8126        70
# 8127        70
# Name: max_power, Length: 8033, dtype: object

# %%
df['max_power'] = df['max_power'].astype(float)
df['max_power'].dtype
# Out:
# dtype('float64')

# %%
df['brand']
# Out:
# 0             Maruti Swift Dzire VDI
# 1       Skoda Rapid 1.5 TDI Ambition
# 2           Honda City 2017-2020 EXi
# 3          Hyundai i20 Sportz Diesel
# 4             Maruti Swift VXI BSIII
#                     ...
# 8123               Hyundai i20 Magna
# 8124           Hyundai Verna CRDi SX
# 8125          Maruti Swift Dzire ZDi
# 8126                 Tata Indigo CR4
# 8127                 Tata Indigo CR4
# Name: brand, Length: 8033, dtype: object

# %%
df['brand'] = df['brand'].str.split(' ').str[0]
df['brand']
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: brand, Length: 8033, dtype: object

# %%
df.drop(columns={'torque'}, inplace=True) #Dropping torque

# %%
df
# Out:
#         brand  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
# 8126     Tata  2013         290000      25000  Diesel  Individual
# 8127     Tata  2013         290000      25000  Diesel  Individual
#
#      transmission  owner  milage  engine  max_power  seats
# 0          Manual      1   23.40  1248.0      74.00    5.0
# 1          Manual      2   21.14  1498.0     103.52    5.0
# 2          Manual      3   17.70  1497.0      78.00    5.0
# 3          Manual      1   23.00  1396.0      90.00    5.0
# 4          Manual      1   16.10  1298.0      88.20    5.0
# ...           ...    ...     ...     ...        ...    ...
# 8123       Manual      1   18.50  1197.0      82.85    5.0
# 8124       Manual      4   16.80  1493.0     110.00    5.0
# 8125       Manual      1   19.30  1248.0      73.90    5.0
# 8126       Manual      1   23.57  1396.0      70.00    5.0
# 8127       Manual      1   23.57  1396.0      70.00    5.0
#
# [8033 rows x 12 columns]

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['owner'].dtype
# Out:
# dtype('int64')

# %%
df = df[df['owner'] !=5] # Removing test drive cars
df['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df['selling_price']
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 8028, dtype: int64

# %%
y = np.log(df['selling_price']) #Transforming y ie selling price using log

y
# Out:
# 0       13.017003
# 1       12.821258
# 2       11.970350
# 3       12.323856
# 4       11.775290
#           ...
# 8123    12.676076
# 8124    11.813030
# 8125    12.853176
# 8126    12.577636
# 8127    12.577636
# Name: selling_price, Length: 8028, dtype: float64

# %%
df.head()
# Out:
#      brand  year  selling_price  km_driven    fuel seller_type transmission  \
# 0   Maruti  2014         450000     145500  Diesel  Individual       Manual
# 1    Skoda  2014         370000     120000  Diesel  Individual       Manual
# 2    Honda  2006         158000     140000  Petrol  Individual       Manual
# 3  Hyundai  2010         225000     127000  Diesel  Individual       Manual
# 4   Maruti  2007         130000     120000  Petrol  Individual       Manual
#
#    owner  milage  engine  max_power  seats
# 0      1   23.40  1248.0      74.00    5.0
# 1      2   21.14  1498.0     103.52    5.0
# 2      3   17.70  1497.0      78.00    5.0
# 3      1   23.00  1396.0      90.00    5.0
# 4      1   16.10  1298.0      88.20    5.0

# %%
sns.countplot(data = df, x = 'owner') # Univariate analysis. Countplot.
# Out:
# <Axes: xlabel='owner', ylabel='count'>

# %%
sns.countplot(data = df, x = 'fuel')
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %%
sns.countplot(data = df, x = 'transmission')
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(data = df, x = 'seats')
# Out:
# <Axes: xlabel='seats', ylabel='count'>

# %%
sns.boxplot(x = df["engine"], y = df["fuel"]); #Boxplot
plt.ylabel("fuel")
plt.xlabel("engine")
# Out:
# Text(0.5, 0, 'engine')

# %%
sns.scatterplot(x = df['milage'], y = df['engine'], hue=df['max_power']) #scatterplot
# Out:
# <Axes: xlabel='milage', ylabel='engine'>

# %%
sns.scatterplot(x = df['milage'], y = df['year'], hue=df['selling_price'])
# Out:
# <Axes: xlabel='milage', ylabel='year'>

# %%
df
# Out:
#         brand  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
# 8126     Tata  2013         290000      25000  Diesel  Individual
# 8127     Tata  2013         290000      25000  Diesel  Individual
#
#      transmission  owner  milage  engine  max_power  seats
# 0          Manual      1   23.40  1248.0      74.00    5.0
# 1          Manual      2   21.14  1498.0     103.52    5.0
# 2          Manual      3   17.70  1497.0      78.00    5.0
# 3          Manual      1   23.00  1396.0      90.00    5.0
# 4          Manual      1   16.10  1298.0      88.20    5.0
# ...           ...    ...     ...     ...        ...    ...
# 8123       Manual      1   18.50  1197.0      82.85    5.0
# 8124       Manual      4   16.80  1493.0     110.00    5.0
# 8125       Manual      1   19.30  1248.0      73.90    5.0
# 8126       Manual      1   23.57  1396.0      70.00    5.0
# 8127       Manual      1   23.57  1396.0      70.00    5.0
#
# [8028 rows x 12 columns]

# %%
print(df['fuel'].unique())
print(df['brand'].unique())
print(df['transmission'].unique())
# Out:
# ['Diesel' 'Petrol']
# ['Maruti' 'Skoda' 'Honda' 'Hyundai' 'Toyota' 'Ford' 'Renault' 'Mahindra'
#  'Tata' 'Chevrolet' 'Fiat' 'Datsun' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Audi' 'Volkswagen' 'BMW' 'Nissan' 'Lexus' 'Jaguar' 'Land' 'MG' 'Volvo'
#  'Daewoo' 'Kia' 'Force' 'Ambassador' 'Ashok' 'Isuzu' 'Opel' 'Peugeot']
# ['Manual' 'Automatic']

# %%
df.dtypes #checking datatypes
# Out:
# brand             object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner              int64
# milage           float64
# engine           float64
# max_power        float64
# seats            float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["fuel"] = le.fit_transform(df["fuel"])

df["fuel"].unique()
 # 0 = diesel and 1 = petrol 
 # transforming object
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4082662538.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fuel"] = le.fit_transform(df["fuel"])
# array([0, 1])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["seller_type"] = le.fit_transform(df["seller_type"])

df["seller_type"].unique() #using fit transform to change object into 1, 0, 2 ie the individual, dealer and trademark dealer
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\1894372868.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["seller_type"] = le.fit_transform(df["seller_type"])
# array([1, 0, 2])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["transmission"] = le.fit_transform(df["transmission"])

df["transmission"].unique()
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\3588422592.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["transmission"] = le.fit_transform(df["transmission"])
# array([1, 0])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["brand"] = le.fit_transform(df["brand"])

df["brand"].unique() #assigning brand names of cars with numeric values
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\3341274267.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["brand"] = le.fit_transform(df["brand"])
# array([20, 27, 10, 11, 29,  9, 26, 19, 28,  4,  7,  6, 14, 21, 22,  2, 30,
#         3, 23, 17, 13, 16, 18, 31,  5, 15,  8,  0,  1, 12, 24, 25])

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm") # plotting the corelation matrix
# Out:
# <Axes: >

# %%
df = df.drop(columns=['year', 'transmission', 'owner'])
df # dropping the columns year, transmission and owners
# Out:
#       brand  selling_price  km_driven  fuel  seller_type  milage  engine  \
# 0        20         450000     145500     0            1   23.40  1248.0
# 1        27         370000     120000     0            1   21.14  1498.0
# 2        10         158000     140000     1            1   17.70  1497.0
# 3        11         225000     127000     0            1   23.00  1396.0
# 4        20         130000     120000     1            1   16.10  1298.0
# ...     ...            ...        ...   ...          ...     ...     ...
# 8123     11         320000     110000     1            1   18.50  1197.0
# 8124     11         135000     119000     0            1   16.80  1493.0
# 8125     20         382000     120000     0            1   19.30  1248.0
# 8126     28         290000      25000     0            1   23.57  1396.0
# 8127     28         290000      25000     0            1   23.57  1396.0
#
#       max_power  seats
# 0         74.00    5.0
# 1        103.52    5.0
# 2         78.00    5.0
# 3         90.00    5.0
# 4         88.20    5.0
# ...         ...    ...
# 8123      82.85    5.0
# 8124     110.00    5.0
# 8125      73.90    5.0
# 8126      70.00    5.0
# 8127      70.00    5.0
#
# [8028 rows x 9 columns]

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm") # corelation matrix of the features we will take for the model (x and y )
# Out:
# <Axes: >

# %%
X = df[['brand', 'km_driven', 'fuel', 'seller_type', 'milage', 'engine', 'max_power', 'seats']]
y = df['selling_price'] #feature engineering the data x are the features we use to get the y where y is the selling price of cars

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42) # Splitting the data into train set and test set

# %%
X_train[['brand', 'km_driven', 'fuel', 'seller_type', 'milage', 'engine', 'max_power', 'seats']].isna().sum() # finding the null values in x
# Out:
# brand            0
# km_driven        0
# fuel             0
# seller_type      0
# milage         154
# engine         154
# max_power      149
# seats          154
# dtype: int64

# %%
y_train.isna().sum() #finding the null values in y
# Out:
# np.int64(0)

# %%
sns.displot(data=df, x='milage') # plotting the data

# %%
sns.displot(data=df, x='engine')

# %%
sns.displot(data=df, x='max_power')

# %%
sns.displot(data=df, x='seats')

# %%
X_train['milage'].fillna(X_train['milage'].median(), inplace=True)
X_train['engine'].fillna(X_train['engine'].median(), inplace=True)
X_train['seats'].fillna(X_train['seats'].median(), inplace=True)
X_train['max_power'].fillna(X_train['max_power'].median(), inplace=True) # filling the null data in the x of the trainset with the median
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4222864031.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train['milage'].fillna(X_train['milage'].median(), inplace=True)
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4222864031.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train['engine'].fillna(X_train['engine'].median(), inplace=True)
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4222864031.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train['seats'].fillna(X_train['seats'].median(), inplace=True)
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4222864031.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train['max_power'].fillna(X_train['max_power'].median(), inplace=True) # filling the null data in the x of the trainset with the median

# %%
X_train['seats'].isna().sum()
# Out:
# np.int64(0)

# %%
X_train[['brand', 'km_driven', 'fuel', 'seller_type', 'milage', 'engine', 'max_power', 'seats']].isna().sum() # checking if the x train dataset has any null values. it does not. the values have been imputed.
# Out:
# brand          0
# km_driven      0
# fuel           0
# seller_type    0
# milage         0
# engine         0
# max_power      0
# seats          0
# dtype: int64

# %%
X_test['milage'].fillna(X_test['milage'].median(), inplace=True)
X_test['engine'].fillna(X_test['engine'].median(), inplace=True)
X_test['seats'].fillna(X_test['seats'].median(), inplace=True)
X_test['max_power'].fillna(X_test['max_power'].median(), inplace=True) 

# filling data in test set
# Out:
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\2144099587.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test['milage'].fillna(X_test['milage'].median(), inplace=True)
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\2144099587.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test['engine'].fillna(X_test['engine'].median(), inplace=True)
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\2144099587.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test['seats'].fillna(X_test['seats'].median(), inplace=True)
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\2144099587.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test['max_power'].fillna(X_test['max_power'].median(), inplace=True)

# %%
X_test[['brand', 'km_driven', 'fuel', 'seller_type', 'milage', 'engine', 'max_power', 'seats']].isna().sum() # checking if the test set has null values.
# Out:
# brand          0
# km_driven      0
# fuel           0
# seller_type    0
# milage         0
# engine         0
# max_power      0
# seats          0
# dtype: int64

# %%
col_dict = {'brand':1,'km_driven':2, 'fuel':3, 'seller_type':4, 'milage':5, 'engine':6, 'max_power':7, 'seats':8}

# Detect outliers in each variable using box plots.
plt.figure(figsize=(20,30))

for variable,i in col_dict.items():
                     plt.subplot(5,4,i)
                     plt.boxplot(X_train[variable])
                     plt.title(variable)

plt.show()

# %%
def outlier_count(col, data = X_train):
    
    # calculating the 25% quatile and 75% quatile
    q75, q25 = np.percentile(data[col], [75, 25])
    
    # calculate the inter quatile
    iqr = q75 - q25
    
    # min_val and max_val
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    # counting the number of outliers, which are the data that are less than min_val or more than max_val which was calculated above.
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    
    # calculating the percentage of the outliers.
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    
    if(outlier_count > 0):
        print("\n"+15*'-' + col + 15*'-'+"\n")
        print('Number of outliers: {}'.format(outlier_count))
        print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
for col in X_train.columns: #lets check the percentage of outliers in each columns.
    outlier_count(col)
# Out:
# ---------------km_driven---------------
#
# Number of outliers: 102
# Percent of data that is outlier: 1.82%
#
# ---------------seller_type---------------
#
# Number of outliers: 944
# Percent of data that is outlier: 16.8%
#
# ---------------milage---------------
#
# Number of outliers: 14
# Percent of data that is outlier: 0.25%
#
# ---------------engine---------------
#
# Number of outliers: 836
# Percent of data that is outlier: 14.88%
#
# ---------------max_power---------------
#
# Number of outliers: 409
# Percent of data that is outlier: 7.28%
#
# ---------------seats---------------
#
# Number of outliers: 1158
# Percent of data that is outlier: 20.61%

# %%
from sklearn.preprocessing import StandardScaler

# feature scaling the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
# from sklearn.preprocessing import MinMaxScaler

# # Scale X
# scaler_X = MinMaxScaler()
# X_train = scaler_X.fit_transform(X_train)
# X_test  = scaler_X.transform(X_test)

# # Scale y
# scaler_y = MinMaxScaler()
# y_train = scaler_y.fit_transform(y_train.to_numpy().reshape(-1,1)).flatten()
# y_test  = scaler_y.transform(y_test.to_numpy().reshape(-1,1)).flatten()

# %%
print("Shape of x_train: ", X_train.shape) #printing after scaling
print("Shape of x_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of x_train:  (5619, 8)
# Shape of x_test:  (2409, 8)
# Shape of y_train:  (5619,)
# Shape of y_test:  (2409,)

# %%
# from sklearn.linear_model import LinearRegression  #calculating the MSE and r2 using the linear regression model
# from sklearn.metrics import mean_squared_error, r2_score

# lr = LinearRegression()
# lr.fit(x_train, y_train)
# yhat = lr.predict(x_test)

# print("MSE: ", mean_squared_error(y_test, yhat))
# print("r2: ", r2_score(y_test, yhat))

# %%
#!pip install mlflow

# %%
import numpy as np
from sklearn.model_selection import KFold
import mlflow

class LinearRegression(object):
    
    kfold = KFold(n_splits=3)
    
    def __init__(self, regularization, lr=0.001, method='batch', num_epochs=500, batch_size=50,
                 cv=kfold, init_method='zeros', use_momentum=False, momentum=0.9):
        self.lr             = lr
        self.num_epochs     = num_epochs
        self.batch_size     = batch_size
        self.method         = method
        self.cv             = cv
        self.regularization = regularization
        
        self.init_method    = init_method.lower()
        self.use_momentum   = use_momentum
        self.momentum       = momentum
        self.velocity       = None  # for momentum
    
    def mse(self, ytrue, ypred):
        return np.mean((ypred - ytrue)**2)
    
    def r2(self, ytrue, ypred):
        ss_res = np.sum((ytrue - ypred)**2)
        ss_tot = np.sum((ytrue - np.mean(ytrue))**2)
        return 1 - (ss_res / ss_tot)
    
    def _initialize_weights(self, n_features):
        if self.init_method == 'xavier':
            limit = np.sqrt(1 / n_features)
            return np.random.uniform(-limit, limit, size=n_features)
        elif self.init_method == 'zeros':
            return np.zeros(n_features)
        else:
            raise ValueError("init_method must be either 'zeros' or 'xavier'")
    
    def fit(self, X_train, y_train):
        self.kfold_scores = []
        self.val_loss_old = np.inf

        for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
            
            X_cross_train = X_train[train_idx]
            y_cross_train = y_train[train_idx]
            X_cross_val   = X_train[val_idx]
            y_cross_val   = y_train[val_idx]
            
            # Initialize weights
            self.theta = self._initialize_weights(X_cross_train.shape[1])
            
            # Initialize velocity for momentum
            if self.use_momentum:
                self.velocity = np.zeros_like(self.theta)
            
            with mlflow.start_run(run_name=f"Fold-{fold}", nested=True):
                
                params = {"method": self.method, "lr": self.lr, "reg": type(self).__name__,
                          "init_method": self.init_method, "use_momentum": self.use_momentum,
                          "momentum": self.momentum}
                mlflow.log_params(params=params)
                
                for epoch in range(self.num_epochs):
                    perm = np.random.permutation(X_cross_train.shape[0])
                    X_cross_train = X_cross_train[perm]
                    y_cross_train = y_cross_train[perm]
                    
                    if self.method == 'sto':
                        for batch_idx in range(X_cross_train.shape[0]):
                            X_batch = X_cross_train[batch_idx].reshape(1, -1)
                            y_batch = y_cross_train[batch_idx]
                            train_loss = self._train(X_batch, y_batch)
                    elif self.method == 'mini':
                        for batch_idx in range(0, X_cross_train.shape[0], self.batch_size):
                            X_batch = X_cross_train[batch_idx:batch_idx+self.batch_size, :]
                            y_batch = y_cross_train[batch_idx:batch_idx+self.batch_size]
                            train_loss = self._train(X_batch, y_batch)
                    else:
                        X_batch = X_cross_train
                        y_batch = y_cross_train
                        train_loss = self._train(X_batch, y_batch)

                    mlflow.log_metric(key="train_loss", value=train_loss, step=epoch)

                    yhat_val = self.predict(X_cross_val)
                    val_loss_new = self.mse(y_cross_val, yhat_val)
                    mlflow.log_metric(key="val_loss", value=val_loss_new, step=epoch)
                    
                    if np.allclose(val_loss_new, self.val_loss_old):
                        break
                    self.val_loss_old = val_loss_new
            
                self.kfold_scores.append(val_loss_new)
                print(f"Fold {fold}: {val_loss_new}")
                    
    def _train(self, X, y):
        X = X.to_numpy() if hasattr(X, "to_numpy") else X
        y = y.to_numpy() if hasattr(y, "to_numpy") else y
        yhat = self.predict(X)
        m = X.shape[0]
        grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta)
        grad[0]=0 # changes
        if self.use_momentum:
            self.velocity = self.momentum * self.velocity + self.lr * grad
            self.theta = self.theta - self.velocity
        else:
            self.theta = self.theta - self.lr * grad
        return self.mse(y, yhat)
    
    def predict(self, X):
        X = X.to_numpy() if hasattr(X, "to_numpy") else X
        return X @ self.theta
    
    def _coef(self):
        return self.theta[1:]
    
    def _bias(self):
        return self.theta[0]

# %%
class LassoPenalty:
    
    def __init__(self, l):
        self.l = l # lambda value
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.abs(theta))
        
    def derivation(self, theta):
        return self.l * np.sign(theta)
    
class RidgePenalty:
    
    def __init__(self, l):
        self.l = l
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.square(theta))
        
    def derivation(self, theta):
        return self.l * 2 * theta
    
class ElasticPenalty:
    
    def __init__(self, l = 0.1, l_ratio = 0.5):
        self.l = l 
        self.l_ratio = l_ratio

    def __call__(self, theta):  #__call__ allows us to call class as method
        l1_contribution = self.l_ratio * self.l * np.sum(np.abs(theta))
        l2_contribution = (1 - self.l_ratio) * self.l * 0.5 * np.sum(np.square(theta))
        return (l1_contribution + l2_contribution)

    def derivation(self, theta):
        l1_derivation = self.l * self.l_ratio * np.sign(theta)
        l2_derivation = self.l * (1 - self.l_ratio) * theta
        return (l1_derivation + l2_derivation)
    
class NoPenalty:
    def __call__(self, theta):
        return 0
    def derivation(self, theta):
        return np.zeros_like(theta)
    
class Lasso(LinearRegression):
    def __init__(self, method='batch', lr=0.001, l=0.1, init_method='zeros', use_momentum=False, momentum=0.9):
        regularization = LassoPenalty(l)
        super().__init__(regularization, lr, method, init_method=init_method,
                         use_momentum=use_momentum, momentum=momentum)

class Ridge(LinearRegression):
    def __init__(self, method='batch', lr=0.001, l=0.1, init_method='zeros', use_momentum=False, momentum=0.9):
        regularization = RidgePenalty(l)
        super().__init__(regularization, lr, method, init_method=init_method,
                         use_momentum=use_momentum, momentum=momentum)

class ElasticNet(LinearRegression):
    def __init__(self, method='batch', lr=0.001, l=0.1, l_ratio=0.5, init_method='zeros',
                 use_momentum=False, momentum=0.9):
        regularization = ElasticPenalty(l, l_ratio)
        super().__init__(regularization, lr, method, init_method=init_method,
                         use_momentum=use_momentum, momentum=momentum)

# %%
#helper function for looping classnames
import sys

def str_to_class(classname):
    return getattr(sys.modules[__name__], classname)

# %%
# Convert y to 1D numpy arrays (no .reshape!)
y_train = np.array(y_train, dtype=np.float64)
y_test = np.array(y_test, dtype=np.float64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import mlflow

regs = ["Ridge", "Lasso", "ElasticNet"]

for reg in regs:
    params = {
        "method": "batch",
        "lr": 0.005,
        "l": 0.01,
        "init_method": "xavier",
        "use_momentum": True,
        "momentum": 0.9
    }
    if reg == "ElasticNet":
        params["l_ratio"] = 0.5

    type_of_regression = str_to_class(reg)
    model = type_of_regression(**params)

    with mlflow.start_run(run_name=f"{reg}_batch_lr-{params['lr']}"):
        model.fit(X_train, y_train)
        yhat = model.predict(X_test)

        # Metrics
        mse = model.mse(y_test, yhat)
        r2 = model.r2(y_test, yhat)
        mlflow.log_metric("test_mse", mse)
        mlflow.log_metric("test_r2", r2)

        # Parameters
        mlflow.log_param("regression_type", reg)
        mlflow.log_params(params)
# Out:
# Fold 0: 672981349137.753
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/759e3d38fd2749f791f7e0d6063fee0c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: 638962533999.6954
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/29450d55cefd4371b3ff3a8531dba821
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 659906620157.4991
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/45660e2332164b54bc49bd098c5d291b
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Ridge_batch_lr-0.005 at: http://localhost:9000/#/experiments/825546618770816377/runs/f704daa5c235459b87618d1981bf174b
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 0: 671590122739.5983
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/6e8e2dc73ba545688a0f5937074c5c09
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: 638677437372.3344
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/66c1e67e3ab34274966054bdb95a4fb3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 661007057417.2458
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/aa795d33a43b476da4c4ec223bad90fc
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Lasso_batch_lr-0.005 at: http://localhost:9000/#/experiments/825546618770816377/runs/fcfaa4c15aa4452d9985d2e8c02cacce
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 0: 671925868722.5133
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/9133dd8bb85947a8a67b7433a56571b5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: 638732081361.3864
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/ed0c774e36c04b24bc0a4488bbd3db8d
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 676133036519.5577
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/ba3219467d7a478ba68e5eff8a8415d3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run ElasticNet_batch_lr-0.005 at: http://localhost:9000/#/experiments/825546618770816377/runs/7447facfbdee4f648cbce802e35b1114
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377

# %%
# Feature importance
feature_names = X_train.columns if isinstance(X_train, pd.DataFrame) else [f"f{i}" for i in range(X_train.shape[1])]
feature_importance = pd.Series(np.abs(model.theta), index=feature_names)
feature_importance = feature_importance.sort_values(ascending=False)

# --- Feature Importance Plot ---
plt.figure(figsize=(8,5))
sns.barplot(x=feature_importance.values, y=feature_importance.index)
plt.title(f"{reg} Feature Importance")
plt.xlabel("Absolute Coefficient Value")
plt.ylabel("feature")
plt.tight_layout()
plt.show()  # Show in notebook
mlflow.log_figure(plt.gcf(), "feature_importance.png")
plt.close()

# --- Residual Plot ---
residuals = y_test - yhat
plt.figure(figsize=(6,4))
sns.scatterplot(x=yhat, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.title(f"{reg} Residual Plot")
plt.tight_layout()
plt.show()  # Show in notebook
mlflow.log_figure(plt.gcf(), "residual_plot.png")
plt.close()

# --- Predicted vs Actual ---
plt.figure(figsize=(6,6))
sns.scatterplot(x=y_test, y=yhat)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title(f"{reg} Predicted vs Actual")
plt.tight_layout()
plt.show()  # Show in notebook
mlflow.log_figure(plt.gcf(), "predicted_vs_actual.png")
plt.close()

# %%
# # --- Feature Importance Plot ---
# plt.figure(figsize=(8,5))
# sns.barplot(x=feature_importance.values, y=feature_importance.index)
# plt.title(f"{reg} Feature Importance")
# plt.xlabel("Absolute Coefficient Value")
# plt.tight_layout()
# plt.show()  # Show in notebook
# mlflow.log_figure(plt.gcf(), "feature_importance.png")
# plt.close()

# # --- Residual Plot ---
# residuals = y_test - yhat
# plt.figure(figsize=(6,4))
# sns.scatterplot(x=yhat, y=residuals)
# plt.axhline(0, color='red', linestyle='--')
# plt.xlabel("Predicted")
# plt.ylabel("Residuals")
# plt.title(f"{reg} Residual Plot")
# plt.tight_layout()
# plt.show()  # Show in notebook
# mlflow.log_figure(plt.gcf(), "residual_plot.png")
# plt.close()

# # --- Predicted vs Actual ---
# plt.figure(figsize=(6,6))
# sns.scatterplot(x=y_test, y=yhat)
# plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
# plt.xlabel("Actual")
# plt.ylabel("Predicted")
# plt.title(f"{reg} Predicted vs Actual")
# plt.tight_layout()
# plt.show()  # Show in notebook
# mlflow.log_figure(plt.gcf(), "predicted_vs_actual.png")
# plt.close()

# %%
import itertools

# -----------------------------
# Parameter options
# -----------------------------
models = ["Normal", "Lasso", "Ridge", "ElasticNet"]  # model type
degrees = [1, 2]                                     # polynomial degrees
momentums = [False, True]                            # use momentum or not
methods = ["sto", "mini", "batch"]                  # training methods
inits = ["zeros", "xavier"]                          # weight initialization
lrs = [0.01, 0.001, 0.0001]                         # learning rates

# Optional: regularization parameters for Lasso, Ridge, ElasticNet
l_values = [0.01]            # you can expand if needed
l_ratios = [0.5]             # for ElasticNet

# -----------------------------
# Generate all experiment combinations
# -----------------------------
experiment_list = []

for m, d, mom, meth, init, lr in itertools.product(models, degrees, momentums, methods, inits, lrs):
    exp = {
        "model_type": m,
        "degree": d,
        "use_momentum": mom,
        "method": meth,
        "init_method": init,
        "lr": lr
    }
    # Add regularization for applicable models
    if m in ["Lasso", "Ridge"]:
        exp["l"] = l_values[0]
    if m == "ElasticNet":
        exp["l"] = l_values[0]
        exp["l_ratio"] = l_ratios[0]
    
    experiment_list.append(exp)

# -----------------------------
# Summary
# -----------------------------
print(f"Total experiments to run: {len(experiment_list)}")  # 288
experiment_list[:5]  # preview first 5 experiments
# Out:
# Total experiments to run: 288
# [{'model_type': 'Normal',
#   'degree': 1,
#   'use_momentum': False,
#   'method': 'sto',
#   'init_method': 'zeros',
#   'lr': 0.01},
#  {'model_type': 'Normal',
#   'degree': 1,
#   'use_momentum': False,
#   'method': 'sto',
#   'init_method': 'zeros',
#   'lr': 0.001},
#  {'model_type': 'Normal',
#   'degree': 1,
#   'use_momentum': False,
#   'method': 'sto',
#   'init_method': 'zeros',
#   'lr': 0.0001},
#  {'model_type': 'Normal',
#   'degree': 1,
#   'use_momentum': False,
#   'method': 'sto',
#   'init_method': 'xavier',
#   'lr': 0.01},
#  {'model_type': 'Normal',
#   'degree': 1,
#   'use_momentum': False,
#   'method': 'sto',
#   'init_method': 'xavier',
#   'lr': 0.001}]

# %%
def run_experiment(model_type="Ridge", degree=1, use_momentum=False,
                   method='batch', init_method='xavier', lr=0.01, l=0.01, l_ratio=0.5):
    """
    Run a single experiment with all options and log to MLflow.
    """

    # -----------------------
    # Convert to DataFrame if needed
    # -----------------------
    import pandas as pd
    if not isinstance(X_train, pd.DataFrame):
        X_train_df = pd.DataFrame(X_train, columns=[f"x{i}" for i in range(X_train.shape[1])])
        X_test_df  = pd.DataFrame(X_test, columns=[f"x{i}" for i in range(X_test.shape[1])])
    else:
        X_train_df, X_test_df = X_train.copy(), X_test.copy()

    # -----------------------
    # Polynomial transform
    # -----------------------
    if degree > 1:
        from sklearn.preprocessing import PolynomialFeatures
        poly = PolynomialFeatures(degree=degree, include_bias=False)
        X_train_exp = poly.fit_transform(X_train_df)
        X_test_exp  = poly.transform(X_test_df)
        feature_names = poly.get_feature_names_out(X_train_df.columns)
    else:
        X_train_exp, X_test_exp = X_train_df.values, X_test_df.values
        feature_names = X_train_df.columns

    # -----------------------
    # Select and initialize model
    # -----------------------
    if model_type == "Ridge":
        model = Ridge(method=method, lr=lr, l=l, init_method=init_method, use_momentum=use_momentum)
    elif model_type == "Lasso":
        model = Lasso(method=method, lr=lr, l=l, init_method=init_method, use_momentum=use_momentum)
    elif model_type == "ElasticNet":
        model = ElasticNet(method=method, lr=lr, l=l, l_ratio=l_ratio, init_method=init_method, use_momentum=use_momentum)
    else:
        model = LinearRegression(regularization=NoPenalty(), method=method, lr=lr, init_method=init_method, use_momentum=use_momentum)

    # -----------------------
    # MLflow logging
    # -----------------------
    import mlflow
    run_name = f"{model_type}_deg{degree}_{method}_{init_method}_lr{lr}_mom{use_momentum}"
    with mlflow.start_run(run_name=run_name):
        # Fit & predict
        model.fit(X_train_exp, y_train)
        y_pred = model.predict(X_test_exp)

        # Metrics
        mse = model.mse(y_test, y_pred)
        r2  = model.r2(y_test, y_pred)
        mlflow.log_params({
            "model": model_type,
            "degree": degree,
            "use_momentum": use_momentum,
            "method": method,
            "init_method": init_method,
            "lr": lr
        })
        mlflow.log_metric("test_mse", mse)
        mlflow.log_metric("test_r2", r2)

        # Feature importance
        import matplotlib.pyplot as plt
        import pandas as pd
        coef = np.abs(model.theta)
        fi = pd.Series(coef, index=feature_names).sort_values(ascending=False)
        plt.figure(figsize=(8,5))
        fi.plot(kind='bar')
        plt.title(f"Feature Importance ({run_name})")
        plt.show()

        # Save and log figure
        fig_path = f"feature_importance_{run_name}.png"
        plt.savefig(fig_path)
        mlflow.log_artifact(fig_path)
        plt.close()

    return mse, r2

# %%
import mlflow

# 1. Ridge regression with polynomial features, batch method, xavier init, lr=0.01, momentum off
mlflow.end_run()
mse, r2 = run_experiment(
    model_type="Ridge",
    degree=2,
    method='batch',
    init_method='xavier',
    lr=0.01,
    use_momentum=False
)
print(f"Ridge Poly - mse: {mse:.4f}, r2: {r2:.4f}")

# 2. Lasso, normal features, mini-batch, zeros init, lr=0.001, momentum on
mlflow.end_run()
mse, r2 = run_experiment(
    model_type="Lasso",
    degree=1,
    method='mini',
    init_method='zeros',
    lr=0.001,
    use_momentum=True
)
print(f"Lasso Normal - mse: {mse:.4f}, r2: {r2:.4f}")

# 3. ElasticNet, polynomial features, stochastic method, zeros init, lr=0.001, momentum off
mlflow.end_run()
mse, r2 = run_experiment(
    model_type="ElasticNet",
    degree=2,
    method='sto',
    init_method='zeros',
    lr=0.001,
    use_momentum=False
)
print(f"ElasticNet Poly - mse: {mse:.4f}, r2: {r2:.4f}")

# 4. Normal linear regression, normal features, batch, xavier init, lr=0.01, momentum on
mlflow.end_run()
mse, r2 = run_experiment(
    model_type="Normal",
    degree=1,
    method='batch',
    init_method='xavier',
    lr=0.01,
    use_momentum=True
)
print(f"Normal Linear - mse: {mse:.4f}, r2: {r2:.4f}")

# 5. Ridge, normal features, mini-batch, zeros init, lr=0.001, momentum on
mlflow.end_run()
mse, r2 = run_experiment(
    model_type="Ridge",
    degree=1,
    method='mini',
    init_method='zeros',
    lr=0.001,
    use_momentum=True
)
print(f"Ridge Normal - mse: {mse:.4f}, r2: {r2:.4f}")

# 6. Lasso, polynomial features, batch method, xavier init, lr=0.01, momentum off
mlflow.end_run()
mse, r2 = run_experiment(
    model_type="Lasso",
    degree=2,
    method='batch',
    init_method='xavier',
    lr=0.01,
    use_momentum=False
)
print(f"Lasso Poly - mse: {mse:.4f}, r2: {r2:.4f}")

mlflow.end_run()
# Out:
# 🏃 View run adaptable-yak-491 at: http://localhost:9000/#/experiments/825546618770816377/runs/02a0ecf7aed24eb981ef3c1408201720
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4148781283.py:24: RuntimeWarning: overflow encountered in square
#   return np.mean((ypred - ytrue)**2)
# c:\Users\aashu\anaconda3\Lib\site-packages\numpy\_core\_methods.py:136: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# Fold 0: inf
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/4951eaf0b1e74efdb9a36dcd81cfe21b
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: inf
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/a2fc0ffb97ca4e40a9e4adf8444b8dc0
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 242305525293.5532
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/61258ed431b3419d8957feb433488b61
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Ridge_deg2_batch_xavier_lr0.01_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/e7057ee69cda4a0ba8045731c1f4c648
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Ridge Poly - mse: 164449585354.2407, r2: 0.7539
# Fold 0: 670723146947.289
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/2dd3a953c7ca48ef8659c93bb1f68514
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: 641023583853.9343
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/0285b4feb684433dbb435e6fdfa71c2c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 659058783056.7499
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/eeff3ae85010484691e8a5d5e9d571de
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Lasso_deg1_mini_zeros_lr0.001_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/69b46a7a7eef4f4bbfb0338c19d80862
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Lasso Normal - mse: 661462571233.5732, r2: 0.0102
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4148781283.py:24: RuntimeWarning: overflow encountered in square
#   return np.mean((ypred - ytrue)**2)
# c:\Users\aashu\anaconda3\Lib\site-packages\numpy\_core\_methods.py:136: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# Fold 0: inf
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/69ac99decd954b4e85ead10dcce36f5f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: inf
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/61cbf536e4874afebce085ff78178a1f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: inf
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/651104f274224d1a94901456ef190fa8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# c:\Users\aashu\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 🏃 View run ElasticNet_deg2_sto_zeros_lr0.001_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/5bae07c787674f2ba260f154575e021c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# ElasticNet Poly - mse: inf, r2: -inf
# Fold 0: 667909967546.6423
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/d47a71d5671840909606b7f7f36eae2b
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: 638004240433.5115
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/3f0247cf4bea411182770ae8befa17ed
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 660864821056.0829
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/7e3e4fda5e1045c2914abd0cb6c2adb3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Normal_deg1_batch_xavier_lr0.01_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/c223665d86484df9a736553e5e248ac5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Normal Linear - mse: 661556190197.3080, r2: 0.0100
# Fold 0: 670583633428.9542
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/d31859079b4f40f39d43875f70d872d6
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: 640184829301.3356
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/21739d016d4e41b4b3df8450895aa1e7
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 657902730624.976
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/21e0150d21f44a82a5c6c7bb5f200617
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Ridge_deg1_mini_zeros_lr0.001_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/190d0aeeef894ede9bb92be604d3ce0c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Ridge Normal - mse: 661678970518.1202, r2: 0.0099
# C:\Users\aashu\AppData\Local\Temp\ipykernel_9996\4148781283.py:24: RuntimeWarning: overflow encountered in square
#   return np.mean((ypred - ytrue)**2)
# c:\Users\aashu\anaconda3\Lib\site-packages\numpy\_core\_methods.py:136: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# Fold 0: inf
# 🏃 View run Fold-0 at: http://localhost:9000/#/experiments/825546618770816377/runs/e55a72d44b7b48af89ed46030adeabb5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 1: inf
# 🏃 View run Fold-1 at: http://localhost:9000/#/experiments/825546618770816377/runs/b75a637106604cf2901b240b1fef5a27
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Fold 2: 244246242225.74387
# 🏃 View run Fold-2 at: http://localhost:9000/#/experiments/825546618770816377/runs/df86560321ee4e79aea8341b09ada275
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# 🏃 View run Lasso_deg2_batch_xavier_lr0.01_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/21ca9ae652954549a8366f65006340ff
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Lasso Poly - mse: 166283330187.7431, r2: 0.7512

# %%
# print(f"Ridge Poly - mse: {mse:.4f}, r2: {r2:.4f}")
# print(f"Lasso Normal - mse: {mse:.4f}, r2: {r2:.4f}")
# print(f"ElasticNet Poly - mse: {mse:.4f}, r2: {r2:.4f}")
# print(f"Normal Linear - mse: {mse:.4f}, r2: {r2:.4f}")
# print(f"Ridge Normal - mse: {mse:.4f}, r2: {r2:.4f}")
# print(f"Lasso Poly - mse: {mse:.4f}, r2: {r2:.4f}")

# %%
experiment_list = []

# Example hyperparameter grids
model_types = ["Normal", "Ridge", "ElasticNet"]
degrees = [1, 2]
use_momentums = [True, False]
methods = ["sto", "mini", "batch"]
init_methods = ["zeros", "xavier"]
lrs = [0.01, 0.001, 0.0001]
l_values = [0.01, 0.1]        # for Ridge/ElasticNet
l_ratios = [0.5, 0.7]         # for ElasticNet

# Create all combinations
for model_type in model_types:
    for degree in degrees:
        for use_momentum in use_momentums:
            for method in methods:
                for init_method in init_methods:
                    for lr in lrs:
                        # Basic params
                        params = {
                            "model_type": model_type,
                            "degree": degree,
                            "use_momentum": use_momentum,
                            "method": method,
                            "init_method": init_method,
                            "lr": lr,
                        }

                        # Add regularization params for specific models
                        if model_type in ["Ridge", "ElasticNet"]:
                            for l in l_values:
                                params_copy = params.copy()
                                params_copy["l"] = l
                                if model_type == "ElasticNet":
                                    for l_ratio in l_ratios:
                                        params_copy2 = params_copy.copy()
                                        params_copy2["l_ratio"] = l_ratio
                                        experiment_list.append(params_copy2)
                                else:
                                    experiment_list.append(params_copy)
                        else:
                            experiment_list.append(params)

# %%
len(experiment_list)
# Out:
# 504

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def plot_feature_importance(feature_importance):
    """
    feature_importance: pandas Series or dict of feature:importance
    """
    if isinstance(feature_importance, dict):
        feature_importance = pd.Series(feature_importance)
    
    feature_importance = feature_importance.sort_values(ascending=False)
    
    plt.figure(figsize=(10,6))
    plt.barh(feature_importance.index, feature_importance.values)
    plt.gca().invert_yaxis()  # highest importance on top
    plt.xlabel("Importance")
    plt.title("Feature Importance")
    plt.show()

# %%
# %pip install --upgrade flask

# %%
# import mlflow
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import io

# # #Make sure no active run is lingering
# # if mlflow.active_run() is not None:
# #      mlflow.end_run()
# if mlflow.active_run() is not None:
#     print(" Ending lingering active MLflow run")
#     mlflow.end_run()
# try:
#     from mlflow.tracking.fluent import _active_run_stack
#     _active_run_stack.clear()
# except:
#     pass  
   

# results = []  # store all experiment results

# for idx, params in enumerate(experiment_list, 1):
#     run_name = f"{params['model_type']}_deg{params['degree']}_lr{params['lr']}_{params['method']}_{params['init_method']}_mom{params['use_momentum']}"
    
#     try:
#         with mlflow.start_run(run_name=run_name) as run:
#             try:

#                 # Run your model training

#                 mse, r2 = run_experiment(**params)
                
  
#                 # Log parameters and metrics

#                 mlflow.log_params({k: v for k, v in params.items() if v is not None})
#                 mlflow.log_metric("mse", mse)
#                 mlflow.log_metric("r2", r2)
                

#                 # Store results

#                 results.append({**params, "mse": mse, "r2": r2})

#                 # GENERATE PLOTS 


#                 model = params.get('model')  # if your run_experiment returns a trained model
#                 X_test, y_test = params.get('X_test'), params.get('y_test')  # pass them via params

#                 if model is not None and X_test is not None and y_test is not None:
#                     # Predicted values
#                     y_pred = model.predict(X_test)
                    
#                     # Actual vs Predicted
#                     plt.figure(figsize=(6,6))
#                     sns.scatterplot(x=y_test, y=y_pred)
#                     plt.xlabel("Actual")
#                     plt.ylabel("Predicted")
#                     plt.title(f"Actual vs Predicted ({run_name})")
#                     plt.plot([y_test.min(), y_test.max()],
#                              [y_test.min(), y_test.max()], 'r--')
#                     buf = io.BytesIO()
#                     plt.savefig(buf, format='png')
#                     buf.seek(0)
#                     mlflow.log_image(buf, "actual_vs_predicted.png")
#                     plt.close()

#                     # Residuals
#                     residuals = y_test - y_pred
#                     plt.figure(figsize=(6,4))
#                     sns.histplot(residuals, kde=True)
#                     plt.xlabel("Residual")
#                     plt.title(f"Residual Distribution ({run_name})")
#                     buf = io.BytesIO()
#                     plt.savefig(buf, format='png')
#                     buf.seek(0)
#                     mlflow.log_image(buf, "residuals.png")
#                     plt.close()

#                     # Feature importance (if model has it)
#                     if hasattr(model, "coef_"):
#                         feature_importance = pd.Series(model.coef_, index=X_test.columns)
#                         plt.figure(figsize=(8,4))
#                         sns.barplot(x=feature_importance, y=feature_importance.index)
#                         plt.title(f"Feature Importance ({run_name})")
#                         buf = io.BytesIO()
#                         plt.savefig(buf, format='png')
#                         buf.seek(0)
#                         mlflow.log_image(buf, "feature_importance.png")
#                         plt.close()

#             except Exception as inner_e:
#                 print(f"Experiment {idx} failed during training: {inner_e}")
            
#             finally:
#                 if mlflow.active_run() is not None:
#                     mlflow.end_run()

#     except Exception as outer_e:
#         print(f"Could not start experiment {idx}: {outer_e}")

# # Convert results to a DataFrame
# results_df = pd.DataFrame(results)
# print(results_df.head())

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# Make sure no active run is lingering
if mlflow.active_run() is not None:
    mlflow.end_run()

results = []  # store all experiment results

for idx, params in enumerate(experiment_list, 1):
    run_name = f"{params['model_type']}_deg{params['degree']}_lr{params['lr']}_{params['method']}_{params['init_method']}_mom{params['use_momentum']}"
    
    try:
        with mlflow.start_run(run_name=run_name) as run:
            try:
                # -----------------------------
                # 1️⃣ Run your model training
                # -----------------------------
                mse, r2 = run_experiment(**params)
                
                # -----------------------------
                # 2️⃣ Log parameters and metrics
                # -----------------------------
                mlflow.log_params({k: v for k, v in params.items() if v is not None})
                mlflow.log_metric("mse", mse)
                mlflow.log_metric("r2", r2)
                
                # -----------------------------
                # 3️⃣ Store results
                # -----------------------------
                results.append({**params, "mse": mse, "r2": r2})

                # -----------------------------
                # 4️⃣ Generate plots after training
                # -----------------------------
                model = params.get('model')  # if your run_experiment returns a trained model
                X_test, y_test = params.get('X_test'), params.get('y_test')  # pass them via params

                if model is not None and X_test is not None and y_test is not None:
                    # Predicted values
                    y_pred = model.predict(X_test)
                    
                    # Actual vs Predicted
                    plt.figure(figsize=(6,6))
                    sns.scatterplot(x=y_test, y=y_pred)
                    plt.xlabel("Actual")
                    plt.ylabel("Predicted")
                    plt.title(f"Actual vs Predicted ({run_name})")
                    plt.plot([y_test.min(), y_test.max()],
                             [y_test.min(), y_test.max()], 'r--')
                    buf = io.BytesIO()
                    plt.savefig(buf, format='png')
                    buf.seek(0)
                    mlflow.log_image(buf, "actual_vs_predicted.png")
                    plt.close()

                    # Residuals
                    residuals = y_test - y_pred
                    plt.figure(figsize=(6,4))
                    sns.histplot(residuals, kde=True)
                    plt.xlabel("Residual")
                    plt.title(f"Residual Distribution ({run_name})")
                    buf = io.BytesIO()
                    plt.savefig(buf, format='png')
                    buf.seek(0)
                    mlflow.log_image(buf, "residuals.png")
                    plt.close()

                    # Feature importance (if model has it)
                    if hasattr(model, "coef_"):
                        feature_importance = pd.Series(model.coef_, index=X_test.columns)
                        plt.figure(figsize=(8,4))
                        sns.barplot(x=feature_importance, y=feature_importance.index)
                        plt.title(f"Feature Importance ({run_name})")
                        buf = io.BytesIO()
                        plt.savefig(buf, format='png')
                        buf.seek(0)
                        mlflow.log_image(buf, "feature_importance.png")
                        plt.close()

            except Exception as inner_e:
                print(f"Experiment {idx} failed during training: {inner_e}")
            
            finally:
                if mlflow.active_run() is not None:
                    mlflow.end_run()

    except Exception as outer_e:
        print(f"Could not start experiment {idx}: {outer_e}")

# Convert results to a DataFrame
results_df = pd.DataFrame(results)
print(results_df.head())
# Out:
# Experiment 1 failed during training: Run with UUID 2824848d530e4b6e8f15e932dd55b483 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/2824848d530e4b6e8f15e932dd55b483
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 2 failed during training: Run with UUID 506d6ff65539475fba4fb1e1aaa09c58 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/506d6ff65539475fba4fb1e1aaa09c58
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 3 failed during training: Run with UUID a946f22fbc8d4415a75c2afec100339e is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/a946f22fbc8d4415a75c2afec100339e
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 4 failed during training: Run with UUID 013cc9a6bc6a41ac9325e59e0aee8bed is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/013cc9a6bc6a41ac9325e59e0aee8bed
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 5 failed during training: Run with UUID 36eb3327aa6e4d2eada1d9beb5330d8c is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/36eb3327aa6e4d2eada1d9beb5330d8c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 6 failed during training: Run with UUID eefa645bce9b44b78f53ef7da2237e99 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/eefa645bce9b44b78f53ef7da2237e99
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 7 failed during training: Run with UUID f6e4a77a69d6443bb4633f8abfe86425 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f6e4a77a69d6443bb4633f8abfe86425
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 8 failed during training: Run with UUID 9b37eb6ab0db4494ac63ea843a520b7d is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/9b37eb6ab0db4494ac63ea843a520b7d
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 9 failed during training: Run with UUID 64bbb6878a0a4fff895cefc0f0e0f961 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/64bbb6878a0a4fff895cefc0f0e0f961
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 10 failed during training: Run with UUID f8101067e38f4ade99b7af716cd3a9a4 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f8101067e38f4ade99b7af716cd3a9a4
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 11 failed during training: Run with UUID 6f67f68f859546bfa63a562f086ff8b2 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/6f67f68f859546bfa63a562f086ff8b2
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 12 failed during training: Run with UUID ff1e4674f67c45ce8ead660182fec41a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/ff1e4674f67c45ce8ead660182fec41a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 13 failed during training: Run with UUID 564c5585c0664bffa3a1b34333fd5c70 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/564c5585c0664bffa3a1b34333fd5c70
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 14 failed during training: Run with UUID f3e1feae9e4e4f8ebe8c6c283e222b64 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f3e1feae9e4e4f8ebe8c6c283e222b64
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 15 failed during training: Run with UUID c906154aa7dd433cb6ba1c39f59a72d5 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/c906154aa7dd433cb6ba1c39f59a72d5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 16 failed during training: Run with UUID 6386bf536c8043a09ddbc8e15a99592f is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/6386bf536c8043a09ddbc8e15a99592f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 17 failed during training: Run with UUID 3556f483daaa478d92bc73813fee8601 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/3556f483daaa478d92bc73813fee8601
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 18 failed during training: Run with UUID 52b363cb85164929ac8c3ada5ec869a1 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/52b363cb85164929ac8c3ada5ec869a1
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 19 failed during training: Run with UUID 44447f39a56c49e2a9125ff28ab00d94 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_sto_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/44447f39a56c49e2a9125ff28ab00d94
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 20 failed during training: Run with UUID 28ac9a9c22be41e4b4bf819d31467637 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_sto_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/28ac9a9c22be41e4b4bf819d31467637
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 21 failed during training: Run with UUID 4176a74969a04a56914871bac477a7ad is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_sto_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/4176a74969a04a56914871bac477a7ad
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 22 failed during training: Run with UUID 1228e61683a84f50a4b222d7487af7cf is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_sto_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/1228e61683a84f50a4b222d7487af7cf
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 23 failed during training: Run with UUID 1f090bcd7ac442e68b2b21d491b4e984 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_sto_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/1f090bcd7ac442e68b2b21d491b4e984
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 24 failed during training: Run with UUID 3cd1f3d54e6d462f9039729a5ebfa4de is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_sto_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/3cd1f3d54e6d462f9039729a5ebfa4de
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 25 failed during training: Run with UUID 40ef68e377d9496fb3c9bf2cd0ed5783 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_mini_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/40ef68e377d9496fb3c9bf2cd0ed5783
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 26 failed during training: Run with UUID 6ddcf08f24e444818e35343ebb08c061 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_mini_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/6ddcf08f24e444818e35343ebb08c061
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 27 failed during training: Run with UUID 7d1e8fe1867a4912971c89d06a68981d is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_mini_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/7d1e8fe1867a4912971c89d06a68981d
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 28 failed during training: Run with UUID 8093b4257f1141e78256929dc3fd92e7 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/8093b4257f1141e78256929dc3fd92e7
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 29 failed during training: Run with UUID aa219979777d4f058034e2d2c5107743 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/aa219979777d4f058034e2d2c5107743
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 30 failed during training: Run with UUID a5538e3eaa64458eb512ba691f980b71 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a5538e3eaa64458eb512ba691f980b71
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 31 failed during training: Run with UUID cc92e422dcad4d3abb6080293d30e01c is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/cc92e422dcad4d3abb6080293d30e01c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 32 failed during training: Run with UUID 8913bbf35dc240a5b3187293e90e71a8 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/8913bbf35dc240a5b3187293e90e71a8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 33 failed during training: Run with UUID 1ed438b1acbd4620876252ab1a4538d1 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/1ed438b1acbd4620876252ab1a4538d1
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 34 failed during training: Run with UUID 052e114128ea4b2c9f3e373d4562837e is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.01_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/052e114128ea4b2c9f3e373d4562837e
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 35 failed during training: Run with UUID 73f11f78456f42fc9976120b177bbab7 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/73f11f78456f42fc9976120b177bbab7
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 36 failed during training: Run with UUID 02e611af767c46e9842b40ae84ff6d46 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg1_lr0.0001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/02e611af767c46e9842b40ae84ff6d46
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 37 failed during training: Run with UUID 157560b2478b4d76aed99d1bdd8b2830 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/157560b2478b4d76aed99d1bdd8b2830
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 38 failed during training: Run with UUID 5f36d701e0ac49d3bd2b4d00a1d8e785 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/5f36d701e0ac49d3bd2b4d00a1d8e785
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 39 failed during training: Run with UUID b7fedb861f4249f997906d34575e43a5 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/b7fedb861f4249f997906d34575e43a5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 40 failed during training: Run with UUID 24c8c15795aa4edf8e1c4c2328278f1b is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/24c8c15795aa4edf8e1c4c2328278f1b
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 41 failed during training: Run with UUID 76f5fcb7007a4b90b7682038e893dabe is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/76f5fcb7007a4b90b7682038e893dabe
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 42 failed during training: Run with UUID f1b0066e91bd49108a56286850b4acbe is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f1b0066e91bd49108a56286850b4acbe
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 43 failed during training: Run with UUID 4a4e48c96f704d2b9054bbba783881b9 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/4a4e48c96f704d2b9054bbba783881b9
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 44 failed during training: Run with UUID 93ef5ebff75d4f1ab53134a3b940e1e7 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/93ef5ebff75d4f1ab53134a3b940e1e7
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 45 failed during training: Run with UUID c3382a7bdb2f41a5a1f12f0a73178d77 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/c3382a7bdb2f41a5a1f12f0a73178d77
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 46 failed during training: Run with UUID 0efe8dade35b4129a6306f25f189098a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/0efe8dade35b4129a6306f25f189098a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 47 failed during training: Run with UUID 7ab9294dd99a4223b265a382436bcc62 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/7ab9294dd99a4223b265a382436bcc62
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 48 failed during training: Run with UUID aeddeab6124a413db5147ee582e44646 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/aeddeab6124a413db5147ee582e44646
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 49 failed during training: Run with UUID e6534de19d59468c919a2d5fae884eb3 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/e6534de19d59468c919a2d5fae884eb3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 50 failed during training: Run with UUID 68937a941ebd4925b2c26c6f7610143e is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/68937a941ebd4925b2c26c6f7610143e
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 51 failed during training: Run with UUID f97e0d0e9b854bffaeeb9f3fe747edff is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f97e0d0e9b854bffaeeb9f3fe747edff
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 52 failed during training: Run with UUID 63c4bf0d5b334e27a827f6bbb308497b is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/63c4bf0d5b334e27a827f6bbb308497b
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 53 failed during training: Run with UUID 5701c08ed2564aacac1df08474c7d6d9 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/5701c08ed2564aacac1df08474c7d6d9
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 54 failed during training: Run with UUID b27b5679f6c04060892d9cdca677c20c is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/b27b5679f6c04060892d9cdca677c20c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 55 failed during training: Run with UUID ca71bacd2f264c7da06fb7562ca07cb9 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_sto_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/ca71bacd2f264c7da06fb7562ca07cb9
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 56 failed during training: Run with UUID 3fef8af49841452eb1df4411675572cc is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_sto_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/3fef8af49841452eb1df4411675572cc
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 57 failed during training: Run with UUID 633b467e0eb043d1892b884026d61559 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_sto_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/633b467e0eb043d1892b884026d61559
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 58 failed during training: Run with UUID 554de6fe29884a699bfb0b078c3552e3 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_sto_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/554de6fe29884a699bfb0b078c3552e3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 59 failed during training: Run with UUID 8f876e6f69d54427b02b1a744840c189 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_sto_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/8f876e6f69d54427b02b1a744840c189
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 60 failed during training: Run with UUID ad516eda8cc84f6e9906acc872902059 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_sto_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/ad516eda8cc84f6e9906acc872902059
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 61 failed during training: Run with UUID 34fb17355fda4e07b576d59907d10610 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_mini_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/34fb17355fda4e07b576d59907d10610
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 62 failed during training: Run with UUID 3c4181953c96445f9e4809273ad504a8 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_mini_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/3c4181953c96445f9e4809273ad504a8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 63 failed during training: Run with UUID 7bb5ef6b26314c2581c6f8e136fc0646 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_mini_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/7bb5ef6b26314c2581c6f8e136fc0646
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 64 failed during training: Run with UUID cb61a61144824bb7b99ca4c8ffd59f54 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/cb61a61144824bb7b99ca4c8ffd59f54
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 65 failed during training: Run with UUID bac12cc5a24946a98ab4bef552511b7f is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/bac12cc5a24946a98ab4bef552511b7f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 66 failed during training: Run with UUID 52e01a3bd6034ac1b7477dd76e2fd7c0 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/52e01a3bd6034ac1b7477dd76e2fd7c0
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 67 failed during training: Run with UUID a124238d3df7416a9ecc5489be1f5110 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a124238d3df7416a9ecc5489be1f5110
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 68 failed during training: Run with UUID c57504c116cd4694a96ff10e5c30b496 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/c57504c116cd4694a96ff10e5c30b496
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 69 failed during training: Run with UUID f8dae705d9d2483b8f9bc98ff94d18e6 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/f8dae705d9d2483b8f9bc98ff94d18e6
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 70 failed during training: Run with UUID dc09e813dee5456786bfbcb52063dcf3 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.01_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/dc09e813dee5456786bfbcb52063dcf3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 71 failed during training: Run with UUID 2f34cbeaa81c4b9aac393510779b8177 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/2f34cbeaa81c4b9aac393510779b8177
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 72 failed during training: Run with UUID 87b0b6afd1b5452882ffe622189c0ecd is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Normal_deg2_lr0.0001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/87b0b6afd1b5452882ffe622189c0ecd
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 73 failed during training: Run with UUID 450826f5cf844efabb2ee9b339003a0f is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/450826f5cf844efabb2ee9b339003a0f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 74 failed during training: Run with UUID c5a4f2bc83944241a3835869f9317a59 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/c5a4f2bc83944241a3835869f9317a59
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 75 failed during training: Run with UUID 6f0ade64a35240cf915dfa26cd0a0eed is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/6f0ade64a35240cf915dfa26cd0a0eed
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 76 failed during training: Run with UUID f3f9b1b248f442cabb8299db99409665 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f3f9b1b248f442cabb8299db99409665
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 77 failed during training: Run with UUID 5025af64e28f4b24a8308e5da6758db3 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/5025af64e28f4b24a8308e5da6758db3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 78 failed during training: Run with UUID f0e24cb8b8c84c078b5e61aea8905007 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_sto_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/f0e24cb8b8c84c078b5e61aea8905007
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 79 failed during training: Run with UUID 1004a96c8f19450ba4ddf29c0166bc4f is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/1004a96c8f19450ba4ddf29c0166bc4f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 80 failed during training: Run with UUID 959765e2e1fe440a838fe7654829a6ad is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/959765e2e1fe440a838fe7654829a6ad
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 81 failed during training: Run with UUID 3c0153d81d9e42daab236cfce1f34ea8 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/3c0153d81d9e42daab236cfce1f34ea8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 82 failed during training: Run with UUID a342793a97e946bd9b7f8e87ce95f62a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/a342793a97e946bd9b7f8e87ce95f62a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 83 failed during training: Run with UUID c5c5073b955d41c29fe1db5b2b75fd88 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/c5c5073b955d41c29fe1db5b2b75fd88
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 84 failed during training: Run with UUID 125fbba745ff42ba8be0dd6fd03ff055 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_sto_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/125fbba745ff42ba8be0dd6fd03ff055
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 85 failed during training: Run with UUID 08fd575819bc47b6b4141c2941287cf5 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/08fd575819bc47b6b4141c2941287cf5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 86 failed during training: Run with UUID 422d071ad6b047eab8f9ffe3c94380e4 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/422d071ad6b047eab8f9ffe3c94380e4
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 87 failed during training: Run with UUID bd18cb3fa67c4610a18a6acd0d8b22fe is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/bd18cb3fa67c4610a18a6acd0d8b22fe
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 88 failed during training: Run with UUID a045b48bbbde45edae88644d495189ae is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/a045b48bbbde45edae88644d495189ae
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 89 failed during training: Run with UUID 698dd27582b84bf7820df1ede3be8c53 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/698dd27582b84bf7820df1ede3be8c53
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 90 failed during training: Run with UUID 177d8a0032114bb8b2ae8c04747c5426 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_mini_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/177d8a0032114bb8b2ae8c04747c5426
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 91 failed during training: Run with UUID 06ea8c80fad34d0f931a98bbe4b2fedd is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/06ea8c80fad34d0f931a98bbe4b2fedd
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 92 failed during training: Run with UUID 4b95484ae1084f5c9f00d22e7ca658f1 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/4b95484ae1084f5c9f00d22e7ca658f1
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 93 failed during training: Run with UUID 79a53d81f7054d6caed033b4f683f825 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/79a53d81f7054d6caed033b4f683f825
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 94 failed during training: Run with UUID 4078845ff4434e15abd53f475ddfa649 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/4078845ff4434e15abd53f475ddfa649
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 95 failed during training: Run with UUID fc0cdaf06e3647e6818115536e99fc2a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/fc0cdaf06e3647e6818115536e99fc2a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 96 failed during training: Run with UUID 9395a2154ce34a7bb84c92ee6361a68e is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_mini_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/9395a2154ce34a7bb84c92ee6361a68e
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 97 failed during training: Run with UUID 19cc63085bef458087a419bdbf717b9f is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/19cc63085bef458087a419bdbf717b9f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 98 failed during training: Run with UUID a3a90da9399e4fc285f54bd4782ba1b7 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/a3a90da9399e4fc285f54bd4782ba1b7
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 99 failed during training: Run with UUID 707ffdaaa4334494845126cddfd1352a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/707ffdaaa4334494845126cddfd1352a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 100 failed during training: Run with UUID 211542a9c1de4da78bf25a74a98bd9df is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/211542a9c1de4da78bf25a74a98bd9df
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 101 failed during training: Run with UUID 5b0bf88d53f04a328fd1688346ce4348 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/5b0bf88d53f04a328fd1688346ce4348
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 102 failed during training: Run with UUID eb7343fb103d45fe9135c495b7fcb92d is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.0001_batch_zeros_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/eb7343fb103d45fe9135c495b7fcb92d
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 103 failed during training: Run with UUID 64e1605277cd48b48cd0abcbda11784a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/64e1605277cd48b48cd0abcbda11784a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 104 failed during training: Run with UUID 7f821cf14a864d78998fb3773b2a1f5d is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.01_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/7f821cf14a864d78998fb3773b2a1f5d
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 105 failed during training: Run with UUID 6ebb2f48ea06486198963a82401edba0 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/6ebb2f48ea06486198963a82401edba0
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 106 failed during training: Run with UUID 6d9abcccc0f2455693f3ef779e0bc4dc is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run Ridge_deg1_lr0.001_batch_xavier_momTrue at: http://localhost:9000/#/experiments/825546618770816377/runs/6d9abcccc0f2455693f3ef779e0bc4dc
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# ...
# 🏃 View run ElasticNet_deg2_lr0.01_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/ffee0a5c30ef424486595ac4424dc4c8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 471 failed during training: Run with UUID 061fae180162477eb4b5e099e5fa8be0 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/061fae180162477eb4b5e099e5fa8be0
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 472 failed during training: Run with UUID 8e68428c7be54cb0890bc1a97bb8efbc is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/8e68428c7be54cb0890bc1a97bb8efbc
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 473 failed during training: Run with UUID df75a50ef62e498d911d5280044f52e8 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/df75a50ef62e498d911d5280044f52e8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 474 failed during training: Run with UUID d2b5012f886044529aa4515230363bb8 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/d2b5012f886044529aa4515230363bb8
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 475 failed during training: Run with UUID d678b4c1ffd14342a85d99ef6e61ab83 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/d678b4c1ffd14342a85d99ef6e61ab83
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 476 failed during training: Run with UUID a4be5436442f485ea32ae054def32f81 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a4be5436442f485ea32ae054def32f81
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 477 failed during training: Run with UUID a08971e2b31c479ba9609389ed397e2a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a08971e2b31c479ba9609389ed397e2a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 478 failed during training: Run with UUID dcebfdf7bb1a4ada86b5fee8ae77a42a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/dcebfdf7bb1a4ada86b5fee8ae77a42a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 479 failed during training: Run with UUID 32aa9fb4764742efb5a7f45cef0ac31f is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/32aa9fb4764742efb5a7f45cef0ac31f
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 480 failed during training: Run with UUID 75cddec452a84e7794eb1a388aa1c6dd is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_mini_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/75cddec452a84e7794eb1a388aa1c6dd
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 481 failed during training: Run with UUID 60cc7ee2786e493f8863ac47dd1299ad is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/60cc7ee2786e493f8863ac47dd1299ad
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 482 failed during training: Run with UUID 23951af11ec148cba4804a60d5f4589c is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/23951af11ec148cba4804a60d5f4589c
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 483 failed during training: Run with UUID f2d6d267606b401589ccd239db4330b9 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/f2d6d267606b401589ccd239db4330b9
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 484 failed during training: Run with UUID f174a25d63814d419ef7ccd28b38d5d1 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/f174a25d63814d419ef7ccd28b38d5d1
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 485 failed during training: Run with UUID 55f138cfe7114a6fb76453ac9b71cf59 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/55f138cfe7114a6fb76453ac9b71cf59
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 486 failed during training: Run with UUID a59dfb3dca104a91887c36fc1d119dbb is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a59dfb3dca104a91887c36fc1d119dbb
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 487 failed during training: Run with UUID e8749978741c48799cbc113c14a7fdde is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/e8749978741c48799cbc113c14a7fdde
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 488 failed during training: Run with UUID 048bf5452aa34564994d550120d0c832 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/048bf5452aa34564994d550120d0c832
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 489 failed during training: Run with UUID 541f148e860d4936bc68f4f9e6e023cc is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/541f148e860d4936bc68f4f9e6e023cc
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 490 failed during training: Run with UUID a5bf0b54e3384e6e84f3b023112cf2a3 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a5bf0b54e3384e6e84f3b023112cf2a3
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 491 failed during training: Run with UUID 9990f853b5fe43fdaccf5d70db0df6d1 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/9990f853b5fe43fdaccf5d70db0df6d1
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 492 failed during training: Run with UUID 5f687331aa8c4641b362a29ec3cc402e is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_zeros_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/5f687331aa8c4641b362a29ec3cc402e
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 493 failed during training: Run with UUID 2925f722eb144e7c8357fb7bc6e5ebe4 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/2925f722eb144e7c8357fb7bc6e5ebe4
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 494 failed during training: Run with UUID 23d6bf22093b41f3b9efa12628cb616e is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/23d6bf22093b41f3b9efa12628cb616e
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 495 failed during training: Run with UUID 0f1dcc9dca2a4520a9378c46eb748ad5 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/0f1dcc9dca2a4520a9378c46eb748ad5
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 496 failed during training: Run with UUID dab1ece351174f88b907aab130d040cf is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.01_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/dab1ece351174f88b907aab130d040cf
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 497 failed during training: Run with UUID 6852d2a89e81494ca1c9c4894c7d82fa is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/6852d2a89e81494ca1c9c4894c7d82fa
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 498 failed during training: Run with UUID 82ac56ed2c3942f79002cc55f0ea4c04 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/82ac56ed2c3942f79002cc55f0ea4c04
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 499 failed during training: Run with UUID f407e82150914042aa029a8174727616 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/f407e82150914042aa029a8174727616
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 500 failed during training: Run with UUID 6aaf434436744b3baa98cc02de4e70bd is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/6aaf434436744b3baa98cc02de4e70bd
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 501 failed during training: Run with UUID 7584a37bc2c243ad863a06f8364c3684 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/7584a37bc2c243ad863a06f8364c3684
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 502 failed during training: Run with UUID c33a376ee4274634971abe372befff6a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/c33a376ee4274634971abe372befff6a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 503 failed during training: Run with UUID a17f336ca9ea466b8abcbf4371345334 is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/a17f336ca9ea466b8abcbf4371345334
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Experiment 504 failed during training: Run with UUID 7271f222004f45148a07261e615c242a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
# 🏃 View run ElasticNet_deg2_lr0.0001_batch_xavier_momFalse at: http://localhost:9000/#/experiments/825546618770816377/runs/7271f222004f45148a07261e615c242a
# 🧪 View experiment at: http://localhost:9000/#/experiments/825546618770816377
# Empty DataFrame
# Columns: []
# Index: []

# %%
results_df = pd.DataFrame(results)
print("\n📊 Results Summary:")
print(results_df[['model_type', 'degree', 'lr', 'method', 'init_method', 'use_momentum', 'mse', 'r2']].head(10))

# Save to CSV
results_df.to_csv("experiment_results.csv", index=False)
print("\n💾 Results saved to 'experiment_results.csv'")

# Best model
if len(results_df) > 0:
    best_r2 = results_df.loc[results_df['r2'].idxmax()]
    print(f"\n🏆 Best Model:\n{best_r2[['model_type', 'degree', 'lr', 'method', 'init_method', 'use_momentum', 'mse', 'r2']]}")
# Out:
# 📊 Results Summary:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 3
#       1 results_df = pd.DataFrame(results)
#       2 print("\n📊 Results Summary:")
# ----> 3 print(results_df[['model_type', 'degree', 'lr', 'method', 'init_method', 'use_momentum', 'mse', 'r2']].head(10))
#       5 # Save to CSV
#       6 results_df.to_csv("experiment_results.csv", index=False)
#
# File c:\Users\aashu\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\aashu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\aashu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['model_type', 'degree', 'lr', 'method', 'init_method', 'use_momentum',\n       'mse', 'r2'],\n      dtype='object')] are in the [columns]"

# %%
results_df.shape

# %%
results_df.sort_values(by='r2', ascending=False).head(10)

# %%
def summarize_for_debug(X_train, y_train, X_test, y_test, lr, l, num_epochs, batch_size):
    import numpy as np
    import pandas as pd

    print("=== Shapes ===")
    print(f"X_train: {X_train.shape}")
    print(f"y_train: {y_train.shape}")
    print(f"X_test: {X_test.shape}")
    print(f"y_test: {y_test.shape}")
    
    print("\n=== Basic Statistics ===")
    print("X_train (first 5 rows):")
    print(pd.DataFrame(X_train).head())
    print("\ny_train (first 10 values):")
    print(y_train[:10] if len(y_train) > 10 else y_train)
    
    print("\nX_train statistics:")
    print(pd.DataFrame(X_train).describe())
    
    print("\ny_train statistics:")
    if isinstance(y_train, np.ndarray):
        print(pd.Series(y_train).describe())
    else:
        print(y_train.describe())
    
    print("\n=== Hyperparameters ===")
    print(f"Learning rate (lr): {lr}")
    print(f"Regularization (l): {l}")
    print(f"Num epochs: {num_epochs}")
    print(f"Batch size: {batch_size}")

    print("\n=== Feature & target ranges ===")
    print(f"X_train min/max:\n{np.min(X_train, axis=0)} / {np.max(X_train, axis=0)}")
    print(f"y_train min/max: {np.min(y_train)} / {np.max(y_train)}")

summarize_for_debug(
    X_train, y_train, X_test, y_test,
    lr=0.0001, l=0.01, num_epochs=500, batch_size=50
)

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test_orig, y_pred_orig, alpha=0.5)
plt.plot([y_test_orig.min(), y_test_orig.max()], [y_test_orig.min(), y_test_orig.max()], 'r--', lw=2)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Car Prices")
plt.show()

# %%
# Plot residuals
residuals = y_test_orig - y_pred_orig
plt.figure(figsize=(10, 6))
plt.scatter(y_pred_orig, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Price")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# Feature importance analysis
feature_importance = best_model.feature_importances_
sorted_idx = np.argsort(feature_importance)

plt.figure(figsize=(10, 8))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx])
plt.yticks(range(len(sorted_idx)), [X.columns[i] for i in sorted_idx])
plt.xlabel("Feature Importance")
plt.title("Random Forest Feature Importance")
plt.show()
# numerical values of feature importance
for i in sorted_idx:
    print(f"{X.columns[i]}: {feature_importance[i]:.4f}")

# %%
# Permutation importance
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(best_model, X_test_scaled, y_test, n_repeats=10, random_state=42)
sorted_idx = perm_importance.importances_mean.argsort()

plt.figure(figsize=(10, 8))
plt.barh(range(len(sorted_idx)), perm_importance.importances_mean[sorted_idx])
plt.yticks(range(len(sorted_idx)), [X.columns[i] for i in sorted_idx])
plt.xlabel("Permutation Importance")
plt.title("Permutation Feature Importance")
plt.show()

# %%
# Save the model and preprocessing objects for Flask app
model_data = {
    'model': best_model,
    'scaler': scaler,
    'le_dict': le_dict,
    'feature_cols': feature_cols,
    'feature_importance': feature_importance
}

with open('app/model/car_price_model.pkl', 'wb') as f:
    pickle.dump(model_data, f)

print("Model and preprocessing objects saved to 'car_price_model.pkl'")

# %%
# Create a prediction function for demonstration
def predict_car_price(input_data, model_data):
    """
    Predict car price based on input features.
    
    Parameters:
    input_data (dict): Dictionary containing feature values
    model_data (dict): Contains model, scaler, label encoders, and feature columns
    
    Returns:
    float: Predicted car price
    """
    model = model_data['model']
    scaler = model_data['scaler']
    le_dict = model_data['le_dict']
    feature_cols = model_data['feature_cols']
    
    # Prepare input data in the correct order
    processed_data = []
    for col in feature_cols:
        if col in le_dict:  # Categorical feature
            # Handle unseen labels
            try:
                encoded_val = le_dict[col].transform([input_data[col]])[0]
            except ValueError:
                # If label not seen during training, use the first category
                encoded_val = 0
            processed_data.append(encoded_val)
        else:  # Numerical feature
            processed_data.append(input_data[col])
    
    # Convert to array and scale
    sample = np.array(processed_data).reshape(1, -1)
    sample_scaled = scaler.transform(sample)
    
    # Predict and transform back from log scale
    pred_log_price = model.predict(sample_scaled)[0]
    pred_price = np.exp(pred_log_price)
    
    return pred_price

# %%
# Example prediction
example_car = {
    'year': 2018,
    'km_driven': 35000,
    'engine': 1498,
    'max_power': 110,
    'brand': 'Honda',
    'mileage': 17.0
}

predicted_price = predict_car_price(example_car, model_data)
print(f"\nPredicted price for example car: ${predicted_price:,.2f}")
